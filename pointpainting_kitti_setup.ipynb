# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
# !ls /content

# %%
# !mkdir -p /conent/drive/MyDrive/AI_Edge_Contest/6th_AI_Edge_Contest

# %%
# %cd /content/drive/MyDrive/AI_Edge_Contest/6th_AI_Edge_Contest/

# %%
# !ls

# %%
# !if [ ! -d 6th-ai-reference ]; then git clone https://github.com/pometa0507/6th-ai-reference; fi

# %%
# !ls

# %%
# %cd 6th-ai-reference

# %%
# !ls

# %%
# !git pull

# %%
# !pip install -r docker/requirements.txt

# %%
# !if [ ! -d spconv ]; then git clone --depth 1 --recursive https://github.com/traveller59/spconv.git -b v1.2.1; fi

# %%
# %cd ./spconv

# %%
# !if [ ! -f dist/spconv*.whl ]; then SPCONV_FORCE_BUILD_CUDA=1 python setup.py bdist_wheel; fi

# %%
# !pip install ./dist/spconv*.whl

# %%
# !ls

# %%
# %cd ../

# %%
# !pip install --upgrade gdown
import gdown

# %%
# !if [ ! -d second.pytorch/checkpoints/pointpainting ]; then python -c "gdown.download("https://drive.google.com/u/0/uc?id=1uIC9u8nEDkQRsQEuvzVzYIst5azB_OIL", "pointpainting.zip", quiet=False)"; fi

# %%
# !ls

# %%
# !if [ ! -d second.pytorch/checkpoints/pointpainting ]; then unzip pointpainting.zip && mv pointpainting ./second.pytorch/checkpoints; fi

# %%
# !ls ./second.pytorch/checkpoints/pointpainting

# %%
# !ls

# %%
# !if [ ! -d mynotebook ]; then cp -r notebook mynotebook; fi

# %%
# !ls

# %%
# %cd mynotebook

# %%
# !ls
